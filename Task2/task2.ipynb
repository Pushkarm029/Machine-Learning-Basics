# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#            sex  age  height  weight  waistline  sight_left  sight_right  \
# 0         Male   35     170      75       90.0         1.0          1.0
# 1         Male   30     180      80       89.0         0.9          1.2
# 2         Male   40     165      75       91.0         1.2          1.5
# 3         Male   50     175      80       91.0         1.5          1.2
# 4         Male   50     165      60       80.0         1.0          1.2
# ...        ...  ...     ...     ...        ...         ...          ...
# 991341    Male   45     175      80       92.1         1.5          1.5
# 991342    Male   35     170      75       86.0         1.0          1.5
# 991343  Female   40     155      50       68.0         1.0          0.7
# 991344    Male   25     175      60       72.0         1.5          1.0
# 991345    Male   50     160      70       90.5         1.0          1.5
#
#         hear_left  hear_right  SBP  ...  LDL_chole  triglyceride  hemoglobin  \
# ...

# %%
list(df.columns)
# Out:
# ['sex',
#  'age',
#  'height',
#  'weight',
#  'waistline',
#  'sight_left',
#  'sight_right',
#  'hear_left',
#  'hear_right',
#  'SBP',
#  'DBP',
#  'BLDS',
#  'tot_chole',
#  'HDL_chole',
#  'LDL_chole',
#  'triglyceride',
#  'hemoglobin',
#  'urine_protein',
#  'serum_creatinine',
#  'SGOT_AST',
#  'SGOT_ALT',
#  'gamma_GTP',
#  'SMK_stat_type_cd',
#  'DRK_YN']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991346 entries, 0 to 991345
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               991346 non-null  object
#  1   age               991346 non-null  int64
#  2   height            991346 non-null  int64
#  3   weight            991346 non-null  int64
#  4   waistline         991346 non-null  float64
#  5   sight_left        991346 non-null  float64
#  6   sight_right       991346 non-null  float64
#  7   hear_left         991346 non-null  int64
#  8   hear_right        991346 non-null  int64
#  9   SBP               991346 non-null  int64
#  10  DBP               991346 non-null  int64
#  11  BLDS              991346 non-null  int64
#  12  tot_chole         991346 non-null  int64
#  13  HDL_chole         991346 non-null  int64
#  14  LDL_chole         991346 non-null  int64
#  15  triglyceride      991346 non-null  int64
# ...

# %%
df.sex.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.sex[df.sex == 'Male'] = 1
df.sex[df.sex == 'Female'] = 0
df
# Out:
# C:\Users\pushk\AppData\Local\Temp\ipykernel_3888\693755319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sex[df.sex == 'Male'] = 1
# C:\Users\pushk\AppData\Local\Temp\ipykernel_3888\693755319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sex[df.sex == 'Female'] = 0
#        sex  age  height  weight  waistline  sight_left  sight_right  \
# 0        1   35     170      75       90.0         1.0          1.0
# 1        1   30     180      80       89.0         0.9          1.2
# 2        1   40     165      75       91.0         1.2          1.5
# ...

# %%
df.DRK_YN.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df.DRK_YN[df.DRK_YN == 'Y'] = 1
df.DRK_YN[df.DRK_YN == 'N'] = 0
df
# Out:
# C:\Users\pushk\AppData\Local\Temp\ipykernel_13736\947224967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DRK_YN[df.DRK_YN == 'Y'] = 1
# C:\Users\pushk\AppData\Local\Temp\ipykernel_13736\947224967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DRK_YN[df.DRK_YN == 'N'] = 0
#            sex  age  height  weight  waistline  sight_left  sight_right  \
# 0         Male   35     170      75       90.0         1.0          1.0
# 1         Male   30     180      80       89.0         0.9          1.2
# 2         Male   40     165      75       91.0         1.2          1.5
# ...

# %%
import numpy as np

# %% [markdown]
# # Target Variable
#
# -> DRK_YN (Drinking -> Yes or No)
# -> SMK_stat_type_cd (Smoker -> Type)

# %%
y1 = df['DRK_YN']
df = df.drop('DRK_YN', axis='columns')
y2 = df['SMK_stat_type_cd']
df = df.drop('SMK_stat_type_cd', axis='columns')
df
# Out:
#            sex  age  height  weight  waistline  sight_left  sight_right  \
# 0         Male   35     170      75       90.0         1.0          1.0
# 1         Male   30     180      80       89.0         0.9          1.2
# 2         Male   40     165      75       91.0         1.2          1.5
# 3         Male   50     175      80       91.0         1.5          1.2
# 4         Male   50     165      60       80.0         1.0          1.2
# ...        ...  ...     ...     ...        ...         ...          ...
# 991341    Male   45     175      80       92.1         1.5          1.5
# 991342    Male   35     170      75       86.0         1.0          1.5
# 991343  Female   40     155      50       68.0         1.0          0.7
# 991344    Male   25     175      60       72.0         1.5          1.0
# 991345    Male   50     160      70       90.5         1.0          1.5
#
#         hear_left  hear_right  SBP  ...  tot_chole  HDL_chole  LDL_chole  \
# ...

# %% [markdown]
# ## The goal is to predict smokers and drinkers using body signal data.
# ### ***So, dropping data cols which are not related to body signals***

# %%
ndf = df.drop(['sex','age','height','weight','waistline','sight_left','sight_right','hear_left','hear_right'],axis='columns')
ndf
# Out:
#         SBP  DBP  BLDS  tot_chole  HDL_chole  LDL_chole  triglyceride  \
# 0       120   80    99        193         48        126            92
# 1       130   82   106        228         55        148           121
# 2       120   70    98        136         41         74           104
# 3       145   87    95        201         76        104           106
# 4       138   82   101        199         61        117           104
# ...     ...  ...   ...        ...        ...        ...           ...
# 991341  114   80    88        198         46        125           132
# 991342  119   83    83        133         40         84            45
# 991343  110   70    90        205         96         77           157
# 991344  119   74    69        122         38         73            53
# 991345  133   79    99        225         39        153           163
#
#         hemoglobin  urine_protein  serum_creatinine  SGOT_AST  SGOT_ALT  \
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991346 entries, 0 to 991345
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   SBP               991346 non-null  int64
#  1   DBP               991346 non-null  int64
#  2   BLDS              991346 non-null  int64
#  3   tot_chole         991346 non-null  int64
#  4   HDL_chole         991346 non-null  int64
#  5   LDL_chole         991346 non-null  int64
#  6   triglyceride      991346 non-null  int64
#  7   hemoglobin        991346 non-null  float64
#  8   urine_protein     991346 non-null  int64
#  9   serum_creatinine  991346 non-null  float64
#  10  SGOT_AST          991346 non-null  int64
#  11  SGOT_ALT          991346 non-null  int64
#  12  gamma_GTP         991346 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 98.3 MB

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(13,1,dpi=95, figsize=(15,22))
i = 0
for col in ndf.columns:
    axs[i].boxplot(df[col], vert=False)
    axs[i].set_ylabel(col)
    i+=1
plt.show()

# %% [markdown]
# ### **Combining both target cols**

# %%
y = pd.concat([y1,y2], axis='columns')
y
# Out:
#        DRK_YN  SMK_stat_type_cd
# 0           1                 1
# 1           0                 3
# 2           0                 1
# 3           0                 1
# 4           0                 1
# ...       ...               ...
# 991341      0                 1
# 991342      0                 1
# 991343      1                 3
# 991344      0                 1
# 991345      1                 3
#
# [991346 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
y = np.array(y)
y = y.astype(int)
ndf = np.array(ndf)
ndf = ndf.astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ndf,y, train_size=0.8)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[0, 1],
#        [1, 2],
#        [0, 1],
#        ...,
#        [1, 3],
#        [1, 1],
#        [0, 1]])

# %%
from sklearn.metrics import accuracy_score
n_samples, n_labels = y_pred.shape
accuracies = []

for label_idx in range(n_labels):
    accuracy = accuracy_score(y_test[:, label_idx], y_pred[:, label_idx])
    accuracies.append(accuracy)

average_accuracy = sum(accuracies) / n_labels
average_accuracy
# Out:
# 0.6707368739597519

# %%
from sklearn.metrics import confusion_matrix
n_samples, n_labels = y_pred.shape
matrix1 = confusion_matrix(y_test[:, 1], y_pred[:, 1])
matrix2 = confusion_matrix(y_test[:, 0], y_pred[:, 0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(matrix1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
plt.figure(figsize=(10,7))
sn.heatmap(matrix2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
model2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model2.predict(X_test)

# %%
y_pred
# Out:
# array([[1, 1],
#        [1, 2],
#        [1, 1],
#        ...,
#        [1, 1],
#        [0, 1],
#        [0, 1]])

# %%
from sklearn.metrics import accuracy_score
n_samples, n_labels = y_pred.shape
accuracies = []

for label_idx in range(n_labels):
    accuracy = accuracy_score(y_test[:, label_idx], y_pred[:, label_idx])
    accuracies.append(accuracy)

average_accuracy = sum(accuracies) / n_labels
average_accuracy
# Out:
# 0.5790185101124729

# %%
from sklearn.metrics import confusion_matrix
n_samples, n_labels = y_pred.shape
matrix1 = confusion_matrix(y_test[:, 1], y_pred[:, 1])
matrix2 = confusion_matrix(y_test[:, 0], y_pred[:, 0])

# %%
plt.figure(figsize=(10,7))
sn.heatmap(matrix1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
plt.figure(figsize=(10,7))
sn.heatmap(matrix2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()

# %% [markdown]
# #### sklearn.naive_bayes.BernoulliNB is typically used for binary classification tasks where the target variable is binary (e.g., 0 or 1). so only using it to train model for predict drnker

# %%
model3.fit(X_train, y_train[:, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Machine-Learning-Basics\Task2\task2.ipynb Cell 35 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Machine-Learning-Basics/Task2/task2.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> model3.fit(X_train, y_train[:, 1])
#
# NameError: name 'X_train' is not defined

# %%
y_pred = model3.predict(X_test)
y_pred
# Out:
# array([1, 2, 1, ..., 1, 1, 1])

# %%
accuracy = accuracy_score(y_test[:,1], y_pred)
accuracy
# Out:
# 0.6177686992484995

# %%
matrix3 = confusion_matrix(y_test[:, 1], y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(matrix3, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.neural_network import MLPClassifier
classifier = MLPClassifier()
model4 = MultiOutputClassifier(classifier)
model4.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=MLPClassifier())

# %%
from sklearn.metrics import accuracy_score
y_pred = model4.predict(X_test)
n_samples, n_labels = y_pred.shape
accuracies4 = []

for label_idx in range(n_labels):
    accuracy = accuracy_score(y_test[:, label_idx], y_pred[:, label_idx])
    accuracies4.append(accuracy)

average_accuracy = sum(accuracies4) / n_labels
average_accuracy
# Out:
# 0.6732208604428305

# %% [markdown]
# # Taking Too Much Time

# %%
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
svm_classifier = SVC(kernel='linear')
model = MultiOutputClassifier(svm_classifier)
model.fit(X_train, y_train)

# %% [markdown]
# ### Till now i was taking two Target Variables
# - But accuracy is low (60-67%)
# - so i am doing each part one by one
# - first -> drinkers
# - second -> smokers

# %%
ndf = ndf.drop_duplicates()

# %%
ndf

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(13,1,dpi=95, figsize=(15,22))
i = 0
for col in ndf.columns:
    axs[i].boxplot(ndf[col], vert=False)
    axs[i].set_ylabel(col)
    i+=1
plt.show()

# %%
from collections import Counter #for outliers detection
def detect_outliers(ndf, min_outlier_occurrences, columns):
    outlier_rows = []
    for col in columns:
        q1 = np.nanpercentile(ndf[col], 25)
        q3 = np.nanpercentile(ndf[col], 75)
        iqr = q3 - q1
        outlier_point = 1.5 * iqr
        outliers = ndf[(ndf[col] < q1 - outlier_point) | (ndf[col] > q3 + outlier_point)].index
        outlier_rows.extend(outliers)

    outlier_counts = Counter(outlier_rows)
    outlier_rows_to_drop = [row for row, count in outlier_counts.items() if count >= min_outlier_occurrences]

    return outlier_rows_to_drop


outlier_rows = detect_outliers(ndf, 5, ndf.select_dtypes(["float", "int"]).columns)
ndf = ndf.drop(outlier_rows)

# %%
ndf.isnull().sum()

# %%
ndf.info()

# %%
x1_train, x1_test, y1_train, y1_test  = train_test_split(ndf, y1, test_size=0.2, shuffle = True, random_state=1)
x2_train, x2_test, y2_train, y2_test  = train_test_split(ndf, y2, test_size=0.2, shuffle = True, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler # for encoding and standardization
scaler = StandardScaler()
scaler.fit(x1_train)
x1_train = scaler.transform(x1_train)
x1_test = scaler.transform(x1_test)
scaler.fit(x2_train)
x2_train = scaler.transform(x2_train)
x2_test = scaler.transform(x2_test)

# %% [markdown]
# # SVM

# %%
svm1 = SVC(kernel='rbf')
svm1.fit(x1_train, y1_train)
y1_predict_SVM = svm1.predict(x1_test)
accuracy_Score_SVM = accuracy_score(y1_test, y1_predict_SVM)
print('SVM model accuracy is: {:.2f}%'.format(accuracy_Score_SVM*100))

# %%
matrixsvc1 = confusion_matrix(y1_test, y1_predict_SVM)
plt.figure(figsize=(10,7))
sn.heatmap(matrixsvc1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
svm2 = SVC(kernel='rbf')
svm2.fit(x2_train, y2_train)
y2_predict_SVM = svm2.predict(x2_test)
accuracy_Score_SVM = accuracy_score(y2_test, y2_predict_SVM)
print('SVM model accuracy is: {:.2f}%'.format(accuracy_Score_SVM*100))

# %%
matrixsvc2 = confusion_matrix(y2_test, y2_predict_SVM)
plt.figure(figsize=(10,7))
sn.heatmap(matrixsvc2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb_model1 = XGBClassifier(n_estimators = 600)
xgb_model1.fit(x1_train, y1_train)
pred1_xgb = xgb_model1.predict(x1_test)
accuracy_Score1_xgb = accuracy_score(y1_test, pred1_xgb)
print('XGBoosting model accuracy is: {:.2f}%'.format(accuracy_Score1_xgb*100))

# %%
matrixxgboost1 = confusion_matrix(y1_test, pred1_xgb)
plt.figure(figsize=(10,7))
sn.heatmap(matrixxgboost1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
xgb_model2 = XGBClassifier(n_estimators = 600)
xgb_model2.fit(x2_train, y2_train)
pred2_xgb = xgb_model2.predict(x2_test)
accuracy_Score2_xgb = accuracy_score(y2_test, pred2_xgb)
print('XGBoosting model accuracy is: {:.2f}%'.format(accuracy_Score2_xgb*100))

# %%
matrixxgboost2 = confusion_matrix(y2_test, pred2_xgb)
plt.figure(figsize=(10,7))
sn.heatmap(matrixxgboost2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %% [markdown]
# # Random Forest

# %%
models1 = RandomForestClassifier(n_estimators=500)
models1.fit(x1_train, y1_train)
y1_predict_random = models1.predict(x1_test)
accuracy_Score_random1 = accuracy_score(y1_test, y1_predict_random)
print('RandomForest model accuracy is: {:.2f}%'.format(accuracy_Score_random1*100))

# %%
matrixrandom1 = confusion_matrix(y1_test, y1_predict_random)
plt.figure(figsize=(10,7))
sn.heatmap(matrixrandom1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
models2 = RandomForestClassifier(n_estimators=500)
models2.fit(x2_train, y2_train)
y2_predict_random = models2.predict(x2_test)
accuracy_Score_random2 = accuracy_score(y2_test, y2_predict_random)
print('RandomForest model accuracy is: {:.2f}%'.format(accuracy_Score_random2*100))

# %%
matrixrandom2 = confusion_matrix(y2_test, y2_predict_random)
plt.figure(figsize=(10,7))
sn.heatmap(matrixrandom2, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %% [markdown]
# ### Best Accuracy ->
