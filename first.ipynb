# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("data.csv")
df
# Out:
#    area  price
# 0  3000    120
# 1  4000    140
# 2  3400    130
# 3  5000    170
# 4  4400    165

# %%
# %matplotlib inline
plt.xlabel('price(INR)')
plt.ylabel('area(IDK)')
plt.scatter(df.area,df.price, color = 'red' , marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
plt.scatter(df.area, df.price, color='red')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')

# %%
reg.predict([[3650]])
# Out:
# c:\Users\pushk\.conda\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([136.7316879])
